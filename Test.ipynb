# %%
import torch
import pandas as pd
df_features_label = pd.read_csv('df_train_set_features_label_time_series.csv', index_col=0)
# a = df_features_label.astype('double')
data = torch.tensor(df_features_label.values, dtype=torch.double)
# data
df_features_label.shape
# a.dtypes
# Out:
# (86, 1501)

# %%
data.dtype
data = data.to(dtype=torch.float32)
data
# Out:
# tensor([[1.0271, 1.0274, 1.0269,  ..., 0.5408, 0.5397, 4.0000],
#         [0.1658, 0.1583, 0.1618,  ..., 0.1984, 0.2054, 2.0000],
#         [0.1861, 0.1987, 0.1968,  ..., 0.1909, 0.1980, 2.0000],
#         ...,
#         [1.0381, 1.0414, 1.0378,  ..., 1.0335, 1.0353, 6.0000],
#         [0.2397, 0.2392, 0.2390,  ..., 0.4830, 0.4873, 3.0000],
#         [1.0343, 1.0366, 1.0356,  ..., 1.0339, 1.0351, 6.0000]])

# %%
ten = torch.zeros(df_features_label.shape)
ten.dtype
for i,
# Out:
# torch.float32

# %%
x = torch.empty(5, 3)
x.dtype
# Out:
# torch.float32

# %%
from sklearn.ensemble import RandomForestRegressor
forest_reg = RandomForestRegressor()

forest_reg.fit(housing_prepared, housing_labels)
housing_predictions = forest_reg.predict(housing_prepared)
forest_mse = mean_squared_error(housing_predictions, housing_labels)
forest_rmse = np.sqrt(forest_mse)
print("rmse on whole training set")
print(forest_rmse)
print(forest_reg.feature_importances_)

forest_scores = cross_val_score(forest_reg, housing_prepared, housing_labels, 
                               scoring="neg_mean_squared_error", cv=10)
forest_rmse = np.sqrt(-forest_scores)
print("rmse of cross validation")
display_scores(forest_rmse)
print(forest_reg.feature_importances_)
# Out:
# /usr/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-0c9339320e8d> in <module>
#       2 forest_reg = RandomForestRegressor()
#       3
# ----> 4 forest_reg.fit(housing_prepared, housing_labels)
#       5 housing_predictions = forest_reg.predict(housing_prepared)
#       6 forest_mse = mean_squared_error(housing_predictions, housing_labels)
#
# NameError: name 'housing_prepared' is not defined

# %%
import numpy as np
a = np.array([2.15295647e+01, 8.12531501e+00, 3.97113829e+00, 1.00777250e+01])
print([ "{:0.2f}".format(x) for x in a ])
# Out:
# ['21.53', '8.13', '3.97', '10.08']

# %%
import requests

x = requests.get('https://w3schools.com/python/demopage.htm', timeout=6)

print(x.text)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /mnt/d/Users/billg/Documents/Science/env_test/env/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     159             conn = connection.create_connection(
# --> 160                 (self._dns_host, self.port), self.timeout, **extra_kw
#     161             )
#
# /mnt/d/Users/billg/Documents/Science/env_test/env/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# /mnt/d/Users/billg/Documents/Science/env_test/env/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# ...

# %%
import requests

url = 'https://www.w3schools.com/python/demopage.htm'
x = requests.get(url, proxies={'http': 'http://localhost:7890'}, timeout=6)

print(x.text)
# Out:
# <!DOCTYPE html>
# <html>
# <body>
#
# <h1>This is a Test Page</h1>
#
# </body>
# </html>

# %%
import requests
url = 'https://www.python.org/static/img/python-logo@2x.png'
# myfile = requests.get(url, timeout=6, proxies={'http': 'http://localhost:7890'})
myfile = requests.get(url, timeout=6, proxies={'http': 'http://localhost:7890'})
open('test.png', 'wb').write(myfile.content)
# Out:
# 15770

# %%
import requests
# url = 'https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.tgz'
# url = 'https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.tgz'
url = 'https://raw.githubusercontent.com/ageron/handson-ml/master/'
# myfile = requests.get(url, proxies={'http': 'http://localhost:7890'})
myfile = requests.get(url)
open('housing.tgz', 'wb').write(myfile.content)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /mnt/d/Users/billg/Documents/Science/env_test/env/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     159             conn = connection.create_connection(
# --> 160                 (self._dns_host, self.port), self.timeout, **extra_kw
#     161             )
#
# /mnt/d/Users/billg/Documents/Science/env_test/env/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# /mnt/d/Users/billg/Documents/Science/env_test/env/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# ...

# %%
import requests

url = 'https://w3schools.com/images/pulpit.jpg'

#allow the response to be streamed by setting the 'stream' parameter to True:
x = requests.get(url, stream=False, proxies={'http': 'http://localhost:7890'})

print(x.status_code)
# Out:
# 200

# %%
import requests
url = 'https://raw.githubusercontent.com/django/django/master/setup.py'
myfile = requests.get(url, proxies={'http': 'http://localhost:7890'}, timeout=10, verify=False)
# open('test.txt', 'wb').write(myfile.content)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /mnt/d/Users/billg/Documents/Science/env_test/env/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     159             conn = connection.create_connection(
# --> 160                 (self._dns_host, self.port), self.timeout, **extra_kw
#     161             )
#
# /mnt/d/Users/billg/Documents/Science/env_test/env/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# /mnt/d/Users/billg/Documents/Science/env_test/env/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# ...

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
from six.moves import urllib
# url = 'https://raw.githubusercontent.com/django/django/master/setup.py'
url = 'https://github.com/django/django/master/setup.py'
urllib.request.ProxyHandler(proxies={'http': 'http://localhost:7890'})
urllib.request.urlretrieve(url, 'test.py')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-65-abe64fda3319> in <module>
#       3 url = 'https://github.com/django/django/master/setup.py'
#       4 urllib.request.ProxyHandler(proxies={'http': 'http://localhost:7890'})
# ----> 5 urllib.request.urlretrieve(url, 'test.py')
#
# /usr/lib/python3.7/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     245     url_type, path = splittype(url)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
#     248         headers = fp.info()
#     249
#
# /usr/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ...

# %%
import urllib3
import urllib
urllib?

# %%
import os
import tarfile
from six.moves import urllib

DOWNLOAD_ROOT = "https://raw.githubusercontent.com/ageron/handson-ml/master/"
HOUSING_PATH = os.path.join("datasets", "housing")
HOUSING_URL = DOWNLOAD_ROOT + "datasets/housing/housing.tgz"

def fetch_housing_data(housing_url=HOUSING_URL, housing_path=HOUSING_PATH):
    os.makedirs(housing_path, exist_ok=True)
    tgz_path = os.path.join(housing_path, "housing.tgz")
    proxy = urllib.request.ProxyHandler({'https': 'localhost:7890'})
    opener = urllib.request.build_opener(proxy)
    urllib.request.install_opener(opener)
    urllib.request.urlretrieve(housing_url, tgz_path)
    housing_tgz = tarfile.open(tgz_path)
    housing_tgz.extractall(path=housing_path)
    housing_tgz.close()
    
    
fetch_housing_data()

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
from six.moves import urllib
url = 'https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/README.md'
req = urllib.request.Request(url)
req.set_proxy('localhost:7890', 'http')
urllib.request.urlopen(req)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-78-df57a05e78a2> in <module>
#       3 req = urllib.request.Request(url)
#       4 req.set_proxy('localhost:7890', 'http')
# ----> 5 urllib.request.urlopen(req)
#
# /usr/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /usr/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# /usr/lib/python3.7/urllib/request.py in http_response(self, request, response)
# ...

# %%
from six.moves import urllib
url = 'https://github.com/ageron/handson-ml'
req = urllib.request.Request(url)
req.set_proxy('localhost:7890', 'http')
response = urllib.request.urlopen(req)
print(response.read().decode('utf8'))
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="utf-8">
#   <link rel="dns-prefetch" href="https://github.githubassets.com">
#   <link rel="dns-prefetch" href="https://avatars0.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://avatars1.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://avatars2.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://avatars3.githubusercontent.com">
#   <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">
#   <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">
#
#
#
#   <link crossorigin="anonymous" media="all" integrity="sha512-FG+rXqMOivrAjdEQE7tO4BwM1poGmg70hJFTlNSxjX87grtrZ6UnPR8NkzwUHlQEGviu9XuRYeO8zH9YwvZhdg==" rel="stylesheet" href="https://github.githubassets.com/assets/frameworks-146fab5ea30e8afac08dd11013bb4ee0.css" />
# ...

# %%
import requests
url = 'https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/README.md'
myfile = requests.get(url, proxies={'https': 'localhost:7890'})
open('test.txt', 'wb').write(myfile.content)
# Out:
# 3680

# %%
import requests
url = 'https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.tgz'
myfile = requests.get(url, proxies={'https': 'localhost:7890'})
print(type(myfile))
# open('test.tgz', 'wb').write(myfile.content)
# Out:
# <class 'requests.models.Response'>

# %%
import tarfile
housing_tgz = tarfile.open('test.tgz')
housing_tgz.extractall()
housing_tgz.close()

# %% [markdown]
# # sklearn.linear_model.LinearRegression

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
X = np.array([[1, 1], [1, 2], [2, 2], [2, 3]])
print(X)
# y = 1 * x_0 + 2 * x_1 + 3
y = np.dot(X, np.array([[1], [2]])) + 3
print(y)
reg = LinearRegression().fit(X, y)
print(reg.coef_)
print(reg.intercept_)

print(reg.predict(np.array([[3, 5]])))
# Out:
# [[1 1]
#  [1 2]
#  [2 2]
#  [2 3]]
# [[ 6]
#  [ 8]
#  [ 9]
#  [11]]

# %%
reg.coef_
# Out:
# array([[1., 2.]])

# %%
reg.intercept_
# Out:
# array([3.])

# %%
reg.predict(np.array([[3, 5]]))
# Out:
# array([[16.]])

# %% [markdown]
# # sklearn.impute.SimpleImputer

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
imp_mean.fit([[7, 2, 3], [4, np.nan, 6], [10, 5, 9]])
X = [[np.nan, 2, 3], [4, np.nan, 6], [10, np.nan, 9]]
print(imp_mean.transform(X))
# Out:
# [[ 7.   2.   3. ]
#  [ 4.   3.5  6. ]
#  [10.   3.5  9. ]]

# %%
imp_mean.statistics_
# Out:
# array([7. , 3.5, 6. ])

# %%
imp_mean.indicator_

# %%
from sklearn.impute import SimpleImputer
